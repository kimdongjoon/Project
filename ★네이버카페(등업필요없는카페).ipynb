# %%
pwd
# Out:
# 'd:\\Workspace\\Project'

# %%
import pandas as pd
import numpy as np
import math

from bs4 import BeautifulSoup
from selenium import webdriver
from selenium.webdriver import ActionChains as AC
from selenium.webdriver.common.keys import Keys
from tqdm.notebook import tqdm
import re
from time import sleep
import time
from datetime import datetime, date

# %% [markdown]
# ## 네이버카페 띄우고 자동으로 로그인까지

# %%
## 네이버카페 띄우고 자동으로 로그인까지

# 네이버카페(PC) 크롬창 띄우기
driver = webdriver.Chrome("chromedriver.exe") # 크롬 드라이버 로드
driver.get("https://cafe.naver.com/tang2011")   # 네이버카페 띄우기
time.sleep(2)

# 로그인창 띄우기
driver.find_element_by_css_selector(".gnb_btn_login").click()

# %% [raw]
# # 수동 로그인

# %%
# 전체글보기 클릭
# 스크롤 내리기
import time
def scroll_down(driver):
  driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")   # 스크롤 맨밑까지 다운
  time.sleep(0.4)
i = 0
while i < 1:
  scroll_down(driver)     
  i += 1

# 전체글보기 클릭
driver.find_element_by_css_selector("#menuLink0").click()
time.sleep(1)

# %%
# 검색어 검색

# iframe 접근
driver.switch_to_frame('cafe_main')

# 검색어 입력   
검색어 = "주식"

query_input = driver.find_element_by_css_selector("#query")
driver.find_element_by_css_selector("#query").click()

for c in 검색어:     
    query_input.send_keys(c)     
    time.sleep(0.3)
    
# 검색 버튼 클릭
driver.find_element_by_css_selector('.btn-search-green').click()
# Out:
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\ipykernel_launcher.py:4: DeprecationWarning: use driver.switch_to.frame instead
#   after removing the cwd from sys.path.

# %% [markdown]
# ## 글 URL 수집 (이미 했으면 또 할 필요 없음)

# %%
url_list = []

# 몇 페이지까지 글을 크롤링할지
num_page = 5
for i in range(1, num_page):  # i는 페이지 번호
    # query(검색어)가 입력된 url
    url = "https://cafe.naver.com/tang2011?iframe_url=/ArticleSearchList.nhn%3Fsearch.clubid=23793202%26search.media=0%26search.searchdate=all%26search.defaultValue=1%26userDisplay=15%26search.option=0%26search.sortBy=date%26search.searchBy=0%26search.query=%C1%D6%BD%C4%26search.viewtype=title%26search.page={}".format(i)
    driver.get(url)
    time.sleep(0.5)
    
    # iframe 접근
    driver.switch_to_frame('cafe_main')
    
    # URL 크롤링 시작
    overlays = """.article"""
    article_raw = driver.find_elements_by_css_selector(overlays)               # category
    article_raw
    
    for article in article_raw:
        url = article.get_attribute('href')   
        url_list.append(url)
    
    print(i)

url_list
# Out:
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\ipykernel_launcher.py:12: DeprecationWarning: use driver.switch_to.frame instead
#   if sys.path[0] == '':
# 1
# 2
# 3
# 4
# ['https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4657093&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4656916&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4656915&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4656807&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4656806&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4656805&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4656559&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4655857&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4655772&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4655004&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654348&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654346&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654345&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654344&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=1&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654343&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654342&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654340&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654338&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654337&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654336&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654335&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654333&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654316&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654313&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654308&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654306&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654304&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654302&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654301&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=2&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654300&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654298&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654296&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654294&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654292&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654290&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654274&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654272&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654271&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654270&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654268&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654266&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654265&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654263&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654259&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=3&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654253&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654251&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654250&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654247&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654243&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654210&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4654012&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653979&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653898&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653880&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653879&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653878&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653877&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653876&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653875&referrerAllArticles=true',
#  'https://cafe.naver.com/ca-fe/ArticleRead.nhn?clubid=23793202&page=4&inCafeSearch=true&searchBy=1&query=%EC%A3%BC%EC%8B%9D&includeAll=&exclude=&include=&exact=&searchdate=all&media=0&sortBy=date&articleid=4653874&referrerAllArticles=true']

# %%
df = pd.DataFrame({'url':url_list})
df
# Out:
#                                                   url
# 0   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 1   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 2   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 3   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 4   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 5   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 6   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 7   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 8   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 9   https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 10  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 11  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 12  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 13  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 14  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 15  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 16  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 17  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 18  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 19  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 20  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 21  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 22  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 23  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 24  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 25  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 26  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 27  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 28  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 29  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 30  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 31  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 32  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 33  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 34  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 35  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 36  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 37  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 38  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 39  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 40  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 41  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 42  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 43  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 44  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 45  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 46  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 47  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 48  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 49  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 50  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 51  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 52  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 53  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 54  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 55  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 56  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 57  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 58  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 59  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...

# %%
# "url_list.csv" 저장하기
df.to_csv("url_list.csv")

# %% [markdown]
# ## 글 크롤링

# %%
# "url_list.csv" 불러오기
url_load = pd.read_csv('url_list.csv')        # 기본 모델
url_load
# Out:
#     Unnamed: 0                                                url
# 0            0  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 1            1  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 2            2  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 3            3  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 4            4  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 5            5  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 6            6  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 7            7  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 8            8  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 9            9  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 10          10  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 11          11  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 12          12  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 13          13  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 14          14  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 15          15  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 16          16  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 17          17  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 18          18  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 19          19  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 20          20  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 21          21  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 22          22  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 23          23  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 24          24  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 25          25  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 26          26  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 27          27  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 28          28  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 29          29  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 30          30  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 31          31  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 32          32  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 33          33  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 34          34  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 35          35  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 36          36  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 37          37  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 38          38  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 39          39  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 40          40  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 41          41  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 42          42  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 43          43  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 44          44  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 45          45  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 46          46  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 47          47  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 48          48  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 49          49  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 50          50  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 51          51  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 52          52  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 53          53  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 54          54  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 55          55  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 56          56  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 57          57  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 58          58  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...
# 59          59  https://cafe.naver.com/ca-fe/ArticleRead.nhn?c...

# %% [markdown]
# # 크롤링하기

# %%
dict = {}  # 전체 크롤링 데이터를 담을 그릇

# %%
for i in tqdm(range(0, len(url_load))):
    try:
        # 글 띄우기
        url = url_load['url'][i]
        driver.get(url)   # 최신글 띄우기
        time.sleep(1.5)
        
        # iframe 접근
        driver.switch_to_frame('cafe_main')

        target_info = {}   # 글 하나의 딕셔너리
    #     # 카테고리 크롤링 시작
    #     overlays = "#main-area .inbox .fl a.m-tcol-c"
    #     cate = driver.find_element_by_css_selector(overlays)      # category
    #     category = cate.text
    #     category

        # 제목 크롤링 시작
        overlays = ".title_text"                                 
        tit = driver.find_element_by_css_selector(overlays)         # title
        title = tit.text
        title
        
        # 내용(content) 크롤링 시작
        overlays = ".ContentRenderer"                                  
        cont = driver.find_element_by_css_selector(overlays)        # content
        content = cont.text
        content

        # 작성자(id) 크롤링 시작
        overlays = ".nickname"                                  
        id_ = driver.find_element_by_css_selector(overlays)         # person
        person = id_.text
        person

        # 날짜(date) 크롤링 시작
        overlays = ".date"                
        date_ = driver.find_element_by_css_selector(overlays)        # datetime
        datetime = date_.text
        datetime

        # 댓글(reply) 크롤링 시작
        overlays = ".text_comment"                                  
        reply = driver.find_elements_by_css_selector(overlays)      # re_list
        r_num = len(reply)
        re_list = []       
        for re in reply:    
            re_list.append(re.text)
        replies = ",".join(re_list)
        replies
        
#         # 이미지(image) 크롤링 시작
#         overlays = "article_img.ATTACH_IMAGE"                                 
#         img_tmp = driver.find_elements_by_name(overlays)         # image

#         img_list = []   
#         for img in img_tmp:    
#             img_url = img.get_attribute('src')
#             img_list.append(img_url)
#         image = ",".join(img_list)
#         image 

        # 글 1개 딕셔너리에 크롤링한 데이터 집어넣기
        #target_info['category'] = category
        target_info['title'] = title
        target_info['url'] = url
        target_info['content'] = content
        target_info['person'] = person
        target_info['datetime'] = datetime
        target_info['reply'] = replies
#         target_info['image'] = image

        # 글 전체 딕셔너리에 글 각각 딕셔너리 넣기
        # target_info

        dict[i] = target_info
        time.sleep(1)

        print(i, title)
    
#         alert = driver.switch_to.alert
#         alert.accept()
#         time.sleep(1)
    
    except :    
        alert = driver.switch_to.alert
        alert.accept()
        time.sleep(1)

# 판다스로 만들기
import pandas as pd
result_df = pd.DataFrame.from_dict(dict, 'index')

# result_df.rename(columns={result_df.columns[0] : name}, inplace=True)

# 파일로 저장
result_df.to_excel("navercafe.xlsx")
# Out:
# HBox(children=(FloatProgress(value=0.0, max=60.0), HTML(value='')))
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\ipykernel_launcher.py:9: DeprecationWarning: use driver.switch_to.frame instead
#   if __name__ == '__main__':
# ---------------------------------------------------------------------------
# NoSuchElementException                    Traceback (most recent call last)
# <ipython-input-24-78e14228ba6b> in <module>
#      25         overlays = ".ContentRenderer"
# ---> 26         cont = driver.find_element_by_css_selector(overlays)        # content
#      27         content = cont.text
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element_by_css_selector(self, css_selector)
#     597         """
# --> 598         return self.find_element(by=By.CSS_SELECTOR, value=css_selector)
#     599
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\webdriver.py in find_element(self, by, value)
#     977             'using': by,
# --> 978             'value': value})['value']
#     979
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#
# NoSuchElementException: Message: no such element: Unable to locate element: {"method":"css selector","selector":".ContentRenderer"}
#   (Session info: chrome=84.0.4147.135)
#
#
# During handling of the above exception, another exception occurred:
#
# NoAlertPresentException                   Traceback (most recent call last)
# <ipython-input-24-78e14228ba6b> in <module>
#      84
#      85     except :
# ---> 86         alert = driver.switch_to.alert
#      87         alert.accept()
#      88         time.sleep(1)
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\switch_to.py in alert(self)
#      53         """
#      54         alert = Alert(self._driver)
# ---> 55         alert.text
#      56         return alert
#      57
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\common\alert.py in text(self)
#      65         """
#      66         if self.driver.w3c:
# ---> 67             return self.driver.execute(Command.W3C_GET_ALERT_TEXT)["value"]
#      68         else:
#      69             return self.driver.execute(Command.GET_ALERT_TEXT)["value"]
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\webdriver.py in execute(self, driver_command, params)
#     319         response = self.command_executor.execute(driver_command, params)
#     320         if response:
# --> 321             self.error_handler.check_response(response)
#     322             response['value'] = self._unwrap_value(
#     323                 response.get('value', None))
#
# C:\ProgramData\Anaconda3\envs\tf2\lib\site-packages\selenium\webdriver\remote\errorhandler.py in check_response(self, response)
#     240                 alert_text = value['alert'].get('text')
#     241             raise exception_class(message, screen, stacktrace, alert_text)
# --> 242         raise exception_class(message, screen, stacktrace)
#     243
#     244     def _value_or_default(self, obj, key, default):
#
# NoAlertPresentException: Message: no such alert
#   (Session info: chrome=84.0.4147.135)
